# %%
import re
import numpy as np
import pandas as pd
from pprint import pprint
import nltk

# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
from gensim.models import TfidfModel

# spacy for lemmatization
import spacy

import re
import numpy as np
import pandas as pd
from pprint import pprint
import nltk

# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel

# spacy for lemmatization
import spacy

# Enable logging for gensim - optional
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)

import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)

stop_words = nltk.corpus.stopwords.words('dutch')
stop_words.extend(['kb', 'pdf','nationaal','rapporteur'])

#Install Dutch Spacy with python -m spacy download nl_core_news_sm
#!python -m spacy download nl_core_news_sm
import nl_core_news_sm

# Initialize spacy 'en' model, keeping only tagger component (for efficiency)
#python3 -m spacy download en
nlp = nl_core_news_sm.load()

# Execute Applications/python 3.7/Install Certificates.command
import nltk
nltk.download('stopwords')

df = pd.read_excel('pdf_pages.xlsx')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\oprokopenk001\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def search(doc1):
    total1=pd.read_csv('all_keywords2.csv')
    total2=pd.read_csv('all_keywords.csv')
    total=total1.append(total2)
    keywords = total.groupby('f').apply(lambda x: x.nlargest(100,'t'))
    doc1.split()
    allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']
    texts_out = []
    for sent in doc1.split():
        doc = nlp("".join(sent))
        print(doc)
        texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
    doc=texts_out
    training_data_x = pd.read_excel("synonyms.xlsx")
    X_train = training_data_x.as_matrix()
    syn=pd.DataFrame()
    for index, val in enumerate(doc):
        try:
            syn[str(index)]=(X_train[np.nonzero(X_train ==(val))[0][0],:])
        except:
            syn[str(index)]=" "
    syn_sp=syn.iloc[:,0]
    syn_sp=syn_sp[syn_sp.notnull()]
    search_results= pd.DataFrame([], columns=['f'])
    for i in range(0, len(doc)):
        syn_sp=syn.iloc[:,i]
        syn_sp=syn_sp[syn_sp.notnull()]
        for j in range(0,len(syn_sp)):
            search_results=search_results.append(pd.DataFrame(keywords.f[keywords.s==syn_sp[j]]))
    search_results=search_results.drop_duplicates() 
    return search_results

# %%
doc = input('Type in the search')
# Out:
# Type in the search kind

# %%
df.head()
# Out:
#    pdf_id                                             par_id  \
# 0     0.0                                              <div
# 1     0.0  >1    pagina 1 van 5 > retouradres postbus 203...
# 2     0.0  >   pagina 2 van 5 datum 13 februari 2017  ons...
# 3     0.0  >   pagina 3 van 5 datum 13 februari 2017  ons...
# 4     0.0  >   pagina 4 van 5 datum 13 februari 2017  ons...
#
#                                                  par  \
# 0                                       ['<', 'div']
# 1  ['>', '1', 'pagina', '1', 'van', '5', '>', 're...
# 2  ['>', 'pagina', '2', 'van', '5', 'datum', '13'...
# 3  ['>', 'pagina', '3', 'van', '5', 'datum', '13'...
# 4  ['>', 'pagina', '4', 'van', '5', 'datum', '13'...
#
#                                             keywords  page_num
# 0                                            ['div']       1.0
# 1  ['1', 'pagina', '1', '5', 'retouradres', 'post...       2.0
# 2  ['pagina', '2', '5', 'datum', '13', 'februari'...       3.0
# 3  ['pagina', '3', '5', 'datum', '13', 'februari'...       4.0
# 4  ['pagina', '4', '5', 'datum', '13', 'februari'...       5.0

# %%
search_results=search(doc)

results=df.par_id[df.iloc[:,0].isin(search_results.f)]
# Out:
# kind
# C:\Users\oprokopenk001\AppData\Anaconda\lib\site-packages\ipykernel_launcher.py:15: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   from ipykernel import kernelapp as app

# %%
df_new=df.iloc[:,0:2]

results=df_new[df.iloc[:,0].isin(search_results.f)]

# %%
results
# Out:
#        pdf_id                                             par_id
# 6         1.0                                              <div
# 7         1.0  >1    pagina 1 van 3 > retouradres postbus 203...
# 8         1.0  > pagina 2 van 3 datum 5 april 2017  ons kenme...
# 9         1.0  > pagina 3 van 3 datum 5 april 2017  ons kenme...
# 18        4.0                                              <div
# 19        4.0  >1    pagina 1 van 3 > retouradres postbus 203...
# 20        4.0  > pagina 2 van 3 datum 20 april 2018  ons kenm...
# 21        4.0  > pagina 3 van 3 datum 20 april 2018  ons kenm...
# 22        5.0                                              <div
# 23        5.0  >1    pagina 1 van 3 > retouradres postbus 203...
# 24        5.0  >   pagina 2 van 3 datum 18 februari 2019  ons...
# 25        5.0  >   pagina 3 van 3 datum 18 februari 2019  ons...
# 30        7.0                                              <div
# 31        7.0  >nationaal rapporteur mensenhandeli)qor r~.~da...
# 32        7.0  >ongerubr!ceerddatumdefinitie kwetsbare positi...
# 33        7.0  >ongerubriceerddatumslachtoffer op zich — dus ...
# 34        7.0  >ongerubriceerddatumten slotte vraag ik uw aan...
# 35        8.0                                              <div
# 36        8.0  >nationaal rapporteur mensenhandeli)qor r~.~da...
# 37        8.0  >ongerubr!ceerddatumdefinitie kwetsbare positi...
# 38        8.0  >ongerubriceerddatumslachtoffer op zich — dus ...
# 39        8.0  >ongerubriceerddatumten slotte vraag ik uw aan...
# 40        9.0                                              <div
# 41        9.0  >1    pagina 1 van 2 > retouradres postbus 484...
# 42        9.0  >   pagina 2 van 2  bureau nationaal rapporteu...
# 66       17.0  20130418 speech nationaal rapporteur rantsev c...
# 67       17.0  >1 speech of the  national rapporteur on traff...
# 68       17.0  >2 first my study on a comprehensive, multidis...
# 69       17.0  >3 what i showed is that human trafficking cas...
# 73       19.0  9269 20130529  min szw  commissie dienstverlen...
# ...       ...                                                ...
# 12559   198.0  >2/3  human trafficking comes in various guise...
# 12560   198.0  >3/3  can buy here. clothing made by children’...
# 12565   200.0                                              <div
# 12566   200.0  >1  speech by corinne dettmeijer,  dutch natio...
# 12567   200.0  >2  wonder that the appeal court reached a con...
# 12568   200.0  >3  first of all, let's take the notion in int...
# 12569   200.0  >4  however, now that s. was not subject to th...
# 12570   200.0  >5  standards. but that exception nevertheless...
# 12589   205.0  microsoft word  the concept of exploitation in...
# 12590   205.0  >korvinus, a.g. e.a. (2006). mensenhandel: de ...
# 12591   205.0  >korvinus, a.g. e.a. (2006). mensenhandel: de ...
# 12592   205.0  >korvinus, a.g. e.a. (2006). mensenhandel: de ...
# 12593   205.0  >korvinus, a.g. e.a. (2006). mensenhandel: de ...
# 12594   205.0  >korvinus, a.g. e.a. (2006). mensenhandel: de ...
# 12595   205.0  >korvinus, a.g. e.a. (2006). mensenhandel: de ...
# 12596   205.0  >korvinus, a.g. e.a. (2006). mensenhandel: de ...
# 12597   205.0  >korvinus, a.g. e.a. (2006). mensenhandel: de ...
# 12598   206.0  microsoft word  20121210 toespraak ketenonderz...
# 12599   206.0  > 1toespraak van de  nationaal rapporteur mens...
# 12600   206.0  > 2steeds vaker werken zij vanuit huis, een ke...
# 12601   206.0  > 3partners, wordt vaak uitsluitend gedacht aa...
# 12608   208.0  microsoft word  toespraak nationaal rapporteur...
# 12609   208.0  > 1embargo tot 18 okt. 2012, 12.30 uur toespra...
# 12610   208.0  > 2ook niet in een land waarin volwassen prost...
# 12611   208.0  > 3kernboodschap uit mijn conclusie: die eendu...
# 12612   208.0  > 4mensenhandelzaken. daaraan is de rechter ui...
# 12613   208.0  > 5monitoren. ik wens de rechtspraak veel succ...
# 12621   210.0  week tegen kindermishandeling  boodschap van d...
# 12622   210.0  >statement van de  nationaal rapporteur mensen...
# 12623   210.0  >nergens voor hoeft te schamen. en als je denk...
#
# [3924 rows x 2 columns]

# %%
results.to_csv('results.csv')
